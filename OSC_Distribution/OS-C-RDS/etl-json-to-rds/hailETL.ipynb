# %%
import geopandas as gpd
import psycopg2

# %%
import psycopg2
connection = psycopg2.connect(
    host="localhost", port=5433, database="pythonspatial", user="postgres", password="NoPassword123!")
cursor = connection.cursor()

# cursor.execute("DROP TABLE osdbhail")
# connection.commit()

cursor.execute(
    "CREATE TABLE osdbhail " +
    "(key VARCHAR(24), latitude NUMERIC(12,6), longitude NUMERIC(12,6)," +

    " hailssp1262020dayslargehailpossiblemetric_mean NUMERIC(12,6), " +
    " hailssp1262030dayslargehailpossiblemetric_mean NUMERIC(12,6), " +
    " hailssp1262040dayslargehailpossiblemetric_mean NUMERIC(12,6), " +
    " hailssp1262050dayslargehailpossiblemetric_mean NUMERIC(12,6), " +
    " hailssp1262075dayslargehailpossiblemetric_mean NUMERIC(12,6), " +
    " hailssp1262100dayslargehailpossiblemetric_mean NUMERIC(12,6), " +


    " hailssp5852020dayslargehailpossiblemetric_mean NUMERIC(12,6), " +
    " hailssp5852030dayslargehailpossiblemetric_mean NUMERIC(12,6), " +
    " hailssp5852040dayslargehailpossiblemetric_mean NUMERIC(12,6), " +
    " hailssp5852050dayslargehailpossiblemetric_mean NUMERIC(12,6), " +
    " hailssp5852075dayslargehailpossiblemetric_mean NUMERIC(12,6), " +
    " hailssp5852100dayslargehailpossiblemetric_mean NUMERIC(12,6) " +



    ")"
)

connection.commit()

cursor.execute("CREATE INDEX keyhail_idx ON osdbhail(key)")

connection.commit()
connection.close()

# %%
connection = psycopg2.connect(
            host="localhost", port=5433, database="pythonspatial", user="postgres", password="NoPassword123!")
cursor = connection.cursor()

def insert_hail(key,lat,lon):
    """ insert a new hail into the osdbhail table """
    sql = """INSERT INTO osdbhail(key,latitude,longitude)
             VALUES(%s,%s,%s) ;"""
    try:
   
        cursor.execute(sql, (key,lat,lon))
        connection.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
#     finally:
#         if connection is not None:
#             connection.close()

    return 0


def createKey (latitude,longitude):
    
    key = "{:.2f}".format(latitude)+"{:.2f}".format(longitude)
    return key

#Fill the empty database
lat = -90
count = 0
while lat<=90:
    lon = -180
    while lon<=180:
        key = createKey(lat,lon)
        #print(key)
        insert_hail(key,lat,lon)
        count = count +1
        lon = lon+0.25
    lat=lat+0.25

connection.commit()
connection.close()

# %% [markdown]
# Buffer

# %% [markdown]
# Iterate through data frame and print each row

# %%
import glob


connection = psycopg2.connect(
            host="localhost", port=5433, database="pythonspatial", user="postgres", password="NoPassword123!")
cursor = connection.cursor()

def update_hail(key, field, metric):
    """ update hailssp1262020 based on key """
    if field == "hailssp1262020dayslargehailpossiblemetric_mean":
        sql = """ UPDATE osdbhail
                    SET hailssp1262020dayslargehailpossiblemetric_mean = %s
                    WHERE key = %s"""
    elif field == "hailssp1262030dayslargehailpossiblemetric_mean":
        sql = """ UPDATE osdbhail
                    SET hailssp1262030dayslargehailpossiblemetric_mean = %s
                    WHERE key = %s"""
    elif field == "hailssp1262040dayslargehailpossiblemetric_mean":
        sql = """ UPDATE osdbhail
                    SET hailssp1262040dayslargehailpossiblemetric_mean = %s
                    WHERE key = %s"""
    elif field == "hailssp1262050dayslargehailpossiblemetric_mean":
        sql = """ UPDATE osdbhail
                    SET hailssp1262050dayslargehailpossiblemetric_mean = %s
                    WHERE key = %s"""
    elif field == "hailssp1262075dayslargehailpossiblemetric_mean":
        sql = """ UPDATE osdbhail
                    SET hailssp1262075dayslargehailpossiblemetric_mean = %s
                    WHERE key = %s"""                 
    elif field == "hailssp1262100dayslargehailpossiblemetric_mean":
        sql = """ UPDATE osdbhail
                    SET hailssp1262100dayslargehailpossiblemetric_mean = %s
                    WHERE key = %s"""
                    
    elif field == "hailssp5852020dayslargehailpossiblemetric_mean":
        sql = """ UPDATE osdbhail
                    SET hailssp5852020dayslargehailpossiblemetric_mean = %s
                    WHERE key = %s"""
    elif field == "hailssp5852030dayslargehailpossiblemetric_mean":
        sql = """ UPDATE osdbhail
                    SET hailssp5852030dayslargehailpossiblemetric_mean = %s
                    WHERE key = %s"""
    elif field == "hailssp5852040dayslargehailpossiblemetric_mean":
        sql = """ UPDATE osdbhail
                    SET hailssp5852040dayslargehailpossiblemetric_mean = %s
                    WHERE key = %s"""
    elif field == "hailssp5852050dayslargehailpossiblemetric_mean":
        sql = """ UPDATE osdbhail
                    SET hailssp5852050dayslargehailpossiblemetric_mean = %s
                    WHERE key = %s"""
    elif field == "hailssp5852075dayslargehailpossiblemetric_mean":
        sql = """ UPDATE osdbhail
                    SET hailssp5852075dayslargehailpossiblemetric_mean = %s
                    WHERE key = %s"""
    elif field == "hailssp5852100dayslargehailpossiblemetric_mean":
        sql = """ UPDATE osdbhail
                    SET hailssp5852100dayslargehailpossiblemetric_mean = %s
                    WHERE key = %s"""
    else:
        print("Wrong Metric*:",key,field,metric)
        return 0



    updated_rows = 0
    try:
       
        cursor.execute(sql, (metric, key))
        # get the number of updated rows
        updated_rows = cursor.rowcount
        # Commit the changes to the database
        connection.commit()
        # Close communication with the PostgreSQL database
        #cur.close()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
#     finally:
#         if conn is not None:
#             conn.close()

    return updated_rows


def findFieldHail(peril,scenario,year,metric):
    #print(peril,scenario,year,metric)
    
    
    if (peril=="hail")and (scenario=="ssp126") and (year==2020) and (metric=="dayslargehailpossible"):
        return "hailssp1262020dayslargehailpossiblemetric_mean"
    elif (peril=="hail")and (scenario=="ssp126") and (year==2030) and (metric=="dayslargehailpossible"):
        return "hailssp1262030dayslargehailpossiblemetric_mean"
    elif (peril=="hail")and (scenario=="ssp126") and (year==2040) and (metric=="dayslargehailpossible"):
        return "hailssp1262040dayslargehailpossiblemetric_mean"
    elif (peril=="hail")and (scenario=="ssp126") and (year==2050) and (metric=="dayslargehailpossible"):
        return "hailssp1262050dayslargehailpossiblemetric_mean"
    elif (peril=="hail")and (scenario=="ssp126") and (year==2075) and (metric=="dayslargehailpossible"):
        return "hailssp1262075dayslargehailpossiblemetric_mean"
    elif (peril=="hail")and (scenario=="ssp126") and (year==2100) and (metric=="dayslargehailpossible"):
        return "hailssp1262100dayslargehailpossiblemetric_mean"
    elif (peril=="hail")and (scenario=="ssp585") and (year==2020) and (metric=="dayslargehailpossible"):
        return "hailssp5852020dayslargehailpossiblemetric_mean"
    elif (peril=="hail")and (scenario=="ssp585") and (year==2030) and (metric=="dayslargehailpossible"):
        return "hailssp5852030dayslargehailpossiblemetric_mean"
    elif (peril=="hail")and (scenario=="ssp585") and (year==2040) and (metric=="dayslargehailpossible"):
        return "hailssp5852040dayslargehailpossiblemetric_mean"
    elif (peril=="hail")and (scenario=="ssp585") and (year==2050) and (metric=="dayslargehailpossible"):
        return "hailssp5852050dayslargehailpossiblemetric_mean"
    elif (peril=="hail")and (scenario=="ssp585") and (year==2075) and (metric=="dayslargehailpossible"):
        return "hailssp5852075dayslargehailpossiblemetric_mean"
    elif (peril=="hail")and (scenario=="ssp585") and (year==2100) and (metric=="dayslargehailpossible"):
        return "hailssp5852100dayslargehailpossiblemetric_mean"
    else:
        return "unknown"
    
def createKey (latitude,longitude):
    
    key = "{:.2f}".format(latitude)+"{:.2f}".format(longitude)
    return key
    



#files = []
#files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/hail/fit_v2/daysLargeHailPossible/agg_v3/ssp126/remap_v1/2020/*.geojsons"))
# files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/hail/fit_v2/daysLargeHailPossible/agg_v3/ssp126/remap_v1/2030/*.geojsons"))
# files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/hail/fit_v2/daysLargeHailPossible/agg_v3/ssp126/remap_v1/2040/*.geojsons"))
# files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/hail/fit_v2/daysLargeHailPossible/agg_v3/ssp126/remap_v1/2050/*.geojsons"))
# files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/hail/fit_v2/daysLargeHailPossible/agg_v3/ssp126/remap_v1/2075/*.geojsons"))
# files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/hail/fit_v2/daysLargeHailPossible/agg_v3/ssp126/remap_v1/2100/*.geojsons"))

files = []
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/hail/fit_v2/daysLargeHailPossible/agg_v3/ssp585/remap_v1/2020/*.geojsons"))
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/hail/fit_v2/daysLargeHailPossible/agg_v3/ssp585/remap_v1/2030/*.geojsons"))
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/hail/fit_v2/daysLargeHailPossible/agg_v3/ssp585/remap_v1/2040/*.geojsons"))
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/hail/fit_v2/daysLargeHailPossible/agg_v3/ssp585/remap_v1/2050/*.geojsons"))
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/hail/fit_v2/daysLargeHailPossible/agg_v3/ssp585/remap_v1/2075/*.geojsons"))
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/hail/fit_v2/daysLargeHailPossible/agg_v3/ssp585/remap_v1/2100/*.geojsons"))



# file = files[0]
# print(file)
# hail = gpd.read_file(file)
#print(drought)
# for index,row in hail.iterrows():
#         #print(row)
#         key = createKey(row["latitude"],row["longitude"])
#         field = findFieldHail(row["peril"],row["scenario"],row["year"],row["metric"].lower()) 
#         dayslargehailpossible = row["metric_mean"]
#         print(key,field,dayslargehailpossible)
#         update_hail(key,field,dayslargehailpossible)
    

for file in files:
    print(file)
    hail = gpd.read_file(file)
    #print(fire)
    for index,row in hail.iterrows():
        #print(row)
        key = createKey(row["latitude"],row["longitude"])
        field = findFieldHail(row["peril"],row["scenario"],row["year"],row["metric"].lower()) 
        dayslargehailpossible = row["metric_mean"]
        #print(key,field,dayslargehailpossible)
        update_hail(key,field,dayslargehailpossible)


connection.close()

# %%
import glob

files = []
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/wind/fit_v9/windSpeed100yr/agg_v2/ssp126/remap_v3/2020/*.geojsons"))

for file in files:
    print(file)

# %%
# !pwd
