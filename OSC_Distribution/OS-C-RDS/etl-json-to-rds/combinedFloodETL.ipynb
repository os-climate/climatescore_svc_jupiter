# %%
import geopandas as gpd
import psycopg2

# %%
import psycopg2
connection = psycopg2.connect(
    host="localhost", port=5433, database="pythonspatial", user="postgres", password="NoPassword123!")
cursor = connection.cursor()

# cursor.execute("DROP TABLE osdbcombinedflood")
# connection.commit()

cursor.execute(
    "CREATE TABLE osdbcombinedflood " +
    "(key VARCHAR(24), latitude NUMERIC(12,6), longitude NUMERIC(12,6)," +

    " combinedfloodssp1262020floodedfraction200yrmetric_mean NUMERIC(12,6), " +
    " combinedfloodssp1262030floodedfraction200yrmetric_mean NUMERIC(12,6), " +
    " combinedfloodssp1262040floodedfraction200yrmetric_mean NUMERIC(12,6), " +
    " combinedfloodssp1262050floodedfraction200yrmetric_mean NUMERIC(12,6), " +
    " combinedfloodssp1262075floodedfraction200yrmetric_mean NUMERIC(12,6), " +
    " combinedfloodssp1262100floodedfraction200yrmetric_mean NUMERIC(12,6), " +


    " combinedfloodssp5852020floodedfraction200yrmetric_mean NUMERIC(12,6), " +
    " combinedfloodssp5852030floodedfraction200yrmetric_mean NUMERIC(12,6), " +
    " combinedfloodssp5852040floodedfraction200yrmetric_mean NUMERIC(12,6), " +
    " combinedfloodssp5852050floodedfraction200yrmetric_mean NUMERIC(12,6), " +
    " combinedfloodssp5852075floodedfraction200yrmetric_mean NUMERIC(12,6), " +
    " combinedfloodssp5852100floodedfraction200yrmetric_mean NUMERIC(12,6) " +




    ")"
)

connection.commit()

cursor.execute("CREATE INDEX keycombinedflood_idx ON osdbcombinedflood(key)")

connection.commit()
connection.close()

# %%
connection = psycopg2.connect(
            host="localhost", port=5433, database="pythonspatial", user="postgres", password="NoPassword123!")
cursor = connection.cursor()

def insert_combinedflood(key,lat,lon):
    """ insert a new combinedflood into the osdbcombinedflood table """
    sql = """INSERT INTO osdbcombinedflood(key,latitude,longitude)
             VALUES(%s,%s,%s) ;"""
    try:
   
        cursor.execute(sql, (key,lat,lon))
        connection.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
#     finally:
#         if connection is not None:
#             connection.close()

    return 0


def createKey (latitude,longitude):
    
    key = "{:.2f}".format(latitude)+"{:.2f}".format(longitude)
    return key

#Fill the empty database
lat = -90
count = 0
while lat<=90:
    lon = -180
    while lon<=180:
        key = createKey(lat,lon)
        #print(key)
        insert_combinedflood(key,lat,lon)
        count = count +1
        lon = lon+0.25
    lat=lat+0.25

connection.commit()
connection.close()

# %% [markdown]
# Buffer

# %% [markdown]
# Iterate through data frame and print each row

# %%
import psycopg2
import glob


connection = psycopg2.connect(
            host="localhost", port=5433, database="pythonspatial", user="postgres", password="NoPassword123!")
cursor = connection.cursor()

def update_combinedflood(key, field, metric):
    """ update combinedfloodssp1262020 based on key """
    if field == "combinedfloodssp1262020floodedfraction200yrmetric_mean":
        sql = """ UPDATE osdbcombinedflood
                    SET combinedfloodssp1262020floodedfraction200yrmetric_mean = %s
                    WHERE key = %s"""
    elif field == "combinedfloodssp1262030floodedfraction200yrmetric_mean":
        sql = """ UPDATE osdbcombinedflood
                    SET combinedfloodssp1262030floodedfraction200yrmetric_mean = %s
                    WHERE key = %s"""
    elif field == "combinedfloodssp1262040floodedfraction200yrmetric_mean":
        sql = """ UPDATE osdbcombinedflood
                    SET combinedfloodssp1262040floodedfraction200yrmetric_mean = %s
                    WHERE key = %s"""
    elif field == "combinedfloodssp1262050floodedfraction200yrmetric_mean":
        sql = """ UPDATE osdbcombinedflood
                    SET combinedfloodssp1262050floodedfraction200yrmetric_mean = %s
                    WHERE key = %s"""
    elif field == "combinedfloodssp1262075floodedfraction200yrmetric_mean":
        sql = """ UPDATE osdbcombinedflood
                    SET combinedfloodssp1262075floodedfraction200yrmetric_mean = %s
                    WHERE key = %s"""                 
    elif field == "combinedfloodssp1262100floodedfraction200yrmetric_mean":
        sql = """ UPDATE osdbcombinedflood
                    SET combinedfloodssp1262100floodedfraction200yrmetric_mean = %s
                    WHERE key = %s"""
                    
    elif field == "combinedfloodssp5852020floodedfraction200yrmetric_mean":
        sql = """ UPDATE osdbcombinedflood
                    SET combinedfloodssp5852020floodedfraction200yrmetric_mean = %s
                    WHERE key = %s"""
    elif field == "combinedfloodssp5852030floodedfraction200yrmetric_mean":
        sql = """ UPDATE osdbcombinedflood
                    SET combinedfloodssp5852030floodedfraction200yrmetric_mean = %s
                    WHERE key = %s"""
    elif field == "combinedfloodssp5852040floodedfraction200yrmetric_mean":
        sql = """ UPDATE osdbcombinedflood
                    SET combinedfloodssp5852040floodedfraction200yrmetric_mean = %s
                    WHERE key = %s"""
    elif field == "combinedfloodssp5852050floodedfraction200yrmetric_mean":
        sql = """ UPDATE osdbcombinedflood
                    SET combinedfloodssp5852050floodedfraction200yrmetric_mean = %s
                    WHERE key = %s"""
    elif field == "combinedfloodssp5852075floodedfraction200yrmetric_mean":
        sql = """ UPDATE osdbcombinedflood
                    SET combinedfloodssp5852075floodedfraction200yrmetric_mean = %s
                    WHERE key = %s"""
    elif field == "combinedfloodssp5852100floodedfraction200yrmetric_mean":
        sql = """ UPDATE osdbcombinedflood
                    SET combinedfloodssp5852100floodedfraction200yrmetric_mean = %s
                    WHERE key = %s"""
    else:
        print("Wrong Metric*:",key,field,metric)
        return 0


    updated_rows = 0
    try:
       
        cursor.execute(sql, (metric, key))
        # get the number of updated rows
        updated_rows = cursor.rowcount
        # Commit the changes to the database
        connection.commit()
        # Close communication with the PostgreSQL database
        #cur.close()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
#     finally:
#         if conn is not None:
#             conn.close()

    return updated_rows


def findFieldCombinedFlood(peril,scenario,year,metric):
    #print(peril,scenario,year,metric)
    
    
    if (peril=="combinedFlood")and (scenario=="ssp126") and (year==2020) and (metric=="floodedfraction200yr"):
        return "combinedfloodssp1262020floodedfraction200yrmetric_mean"
    elif (peril=="combinedFlood")and (scenario=="ssp126") and (year==2030) and (metric=="floodedfraction200yr"):
        return "combinedfloodssp1262030floodedfraction200yrmetric_mean"
    elif (peril=="combinedFlood")and (scenario=="ssp126") and (year==2040) and (metric=="floodedfraction200yr"):
        return "combinedfloodssp1262040floodedfraction200yrmetric_mean"
    elif (peril=="combinedFlood")and (scenario=="ssp126") and (year==2050) and (metric=="floodedfraction200yr"):
        return "combinedfloodssp1262050floodedfraction200yrmetric_mean"
    elif (peril=="combinedFlood")and (scenario=="ssp126") and (year==2075) and (metric=="floodedfraction200yr"):
        return "combinedfloodssp1262075floodedfraction200yrmetric_mean"
    elif (peril=="combinedFlood")and (scenario=="ssp126") and (year==2100) and (metric=="floodedfraction200yr"):
        return "combinedfloodssp1262100floodedfraction200yrmetric_mean"
    elif (peril=="combinedFlood")and (scenario=="ssp585") and (year==2020) and (metric=="floodedfraction200yr"):
        return "combinedfloodssp5852020floodedfraction200yrmetric_mean"
    elif (peril=="combinedFlood")and (scenario=="ssp585") and (year==2030) and (metric=="floodedfraction200yr"):
        return "combinedfloodssp5852030floodedfraction200yrmetric_mean"
    elif (peril=="combinedFlood")and (scenario=="ssp585") and (year==2040) and (metric=="floodedfraction200yr"):
        return "combinedfloodssp5852040floodedfraction200yrmetric_mean"
    elif (peril=="combinedFlood")and (scenario=="ssp585") and (year==2050) and (metric=="floodedfraction200yr"):
        return "combinedfloodssp5852050floodedfraction200yrmetric_mean"
    elif (peril=="combinedFlood")and (scenario=="ssp585") and (year==2075) and (metric=="floodedfraction200yr"):
        return "combinedfloodssp5852075floodedfraction200yrmetric_mean"
    elif (peril=="combinedFlood")and (scenario=="ssp585") and (year==2100) and (metric=="floodedfraction200yr"):
        return "combinedfloodssp5852100floodedfraction200yrmetric_mean"
    else:
        return "unknown"

def createKey (latitude,longitude):
    
    key = "{:.2f}".format(latitude)+"{:.2f}".format(longitude)
    return key
    


files = []
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/combinedFlood/fit_v2/floodedFraction200yr/agg_v2/ssp126/remap_v0/2020/*.geojsons")) 
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/combinedFlood/fit_v2/floodedFraction200yr/agg_v2/ssp126/remap_v0/2030/*.geojsons"))
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/combinedFlood/fit_v2/floodedFraction200yr/agg_v2/ssp126/remap_v0/2040/*.geojsons"))
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/combinedFlood/fit_v2/floodedFraction200yr/agg_v2/ssp126/remap_v0/2050/*.geojsons"))
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/combinedFlood/fit_v2/floodedFraction200yr/agg_v2/ssp126/remap_v0/2075/*.geojsons"))
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/combinedFlood/fit_v2/floodedFraction200yr/agg_v2/ssp126/remap_v0/2100/*.geojsons"))

files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/combinedFlood/fit_v2/floodedFraction200yr/agg_v2/ssp585/remap_v0/2020/*.geojsons"))
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/combinedFlood/fit_v2/floodedFraction200yr/agg_v2/ssp585/remap_v0/2030/*.geojsons"))
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/combinedFlood/fit_v2/floodedFraction200yr/agg_v2/ssp585/remap_v0/2040/*.geojsons"))
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/combinedFlood/fit_v2/floodedFraction200yr/agg_v2/ssp585/remap_v0/2050/*.geojsons"))
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/combinedFlood/fit_v2/floodedFraction200yr/agg_v2/ssp585/remap_v0/2075/*.geojsons"))
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/combinedFlood/fit_v2/floodedFraction200yr/agg_v2/ssp585/remap_v0/2100/*.geojsons"))

# file = files[0]
# print(file)
# combinedFlood = gpd.read_file(file)
# #print(precip)
# for index,row in combinedFlood.iterrows():
#         #print(row)
#         key = createKey(row["latitude"],row["longitude"])
#         field = findFieldCombinedFlood(row["peril"],row["scenario"],row["year"],row["metric"].lower()) 
#         floodedfraction200yr = row["metric_mean"]
#         print(key,field,floodedfraction200yr)
#         update_combinedflood(key,field,floodedfraction200yr)
    

for file in files:
    print(file)
    combinedFlood = gpd.read_file(file)
    #print(precip)
    for index,row in combinedFlood.iterrows():
            #print(row)
            key = createKey(row["latitude"],row["longitude"])
            field = findFieldCombinedFlood(row["peril"],row["scenario"],row["year"],row["metric"].lower()) 
            floodedfraction200yr = row["metric_mean"]
            #print(key,field,floodedfraction200yr)
            update_combinedflood(key,field,floodedfraction200yr)


connection.close()

# %%
import glob

files = []
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/wind/fit_v9/windSpeed100yr/agg_v2/ssp126/remap_v3/2020/*.geojsons"))

for file in files:
    print(file)

# %%
# !pwd
