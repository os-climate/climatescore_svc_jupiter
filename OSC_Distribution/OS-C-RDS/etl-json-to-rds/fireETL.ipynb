# %%
import geopandas as gpd
import psycopg2

# %%
import psycopg2
connection = psycopg2.connect(
    host="localhost", port=5433, database="pythonspatial", user="postgres", password="NoPassword123!")
cursor = connection.cursor()

cursor.execute("DROP TABLE osdbfire")
connection.commit()

cursor.execute(
    "CREATE TABLE osdbfire " +
    "(key VARCHAR(24), latitude NUMERIC(12,6), longitude NUMERIC(12,6)," +

    " firessp1262020metric_mean NUMERIC(12,6), " +
    " firessp1262030metric_mean NUMERIC(12,6), " +
    " firessp1262040metric_mean NUMERIC(12,6), " +
    " firessp1262050metric_mean NUMERIC(12,6), " +
    " firessp1262075metric_mean NUMERIC(12,6), " +
    " firessp1262100metric_mean NUMERIC(12,6), " +


    " firessp5852020metric_mean NUMERIC(12,6), " +
    " firessp5852030metric_mean NUMERIC(12,6), " +
    " firessp5852040metric_mean NUMERIC(12,6), " +
    " firessp5852050metric_mean NUMERIC(12,6), " +
    " firessp5852075metric_mean NUMERIC(12,6), " +
    " firessp5852100metric_mean NUMERIC(12,6) " +



    ")"
)

connection.commit()

cursor.execute("CREATE INDEX key_idx ON osdbfire(key)")

connection.commit()
connection.close()
# cursor.execute("INSERT INTO osdbfire (latitude,longitude) VALUES ({},{})".format(0,0))

# connection.commit()

# %%
connection = psycopg2.connect(
            host="localhost", port=5433, database="pythonspatial", user="postgres", password="NoPassword123!")
cursor = connection.cursor()

def insert_fire(key,lat,lon):
    """ insert a new fire into the osdbfire table """
    sql = """INSERT INTO osdbfire(key,latitude,longitude)
             VALUES(%s,%s,%s) ;"""
    try:
   
        cursor.execute(sql, (key,lat,lon))
        connection.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
#     finally:
#         if connection is not None:
#             connection.close()

    return 0


def createKey (latitude,longitude):
    
    key = "{:.2f}".format(latitude)+"{:.2f}".format(longitude)
    return key

#Fill the empty database
lat = -90
count = 0
while lat<=90:
    lon = -180
    while lon<=180:
        key = createKey(lat,lon)
        #print(key)
        insert_fire(key,lat,lon)
        count = count +1
        lon = lon+0.25
    lat=lat+0.25

connection.commit()
connection.close()

# %% [markdown]
# Buffer

# %% [markdown]
# Iterate through data frame and print each row

# %%
import glob


connection = psycopg2.connect(
            host="localhost", port=5433, database="pythonspatial", user="postgres", password="NoPassword123!")
cursor = connection.cursor()

def update_fire(key, field, metric):
    """ update firessp1262020 based on key """
    
    #print(key,field,metric)
    
    #return 0
    if field == "firessp1262020fireProbabilitymetric_mean":
        sql = """ UPDATE osdbfire
                    SET firessp1262020metric_mean = %s
                    WHERE key = %s"""
    elif field == "firessp1262030fireProbabilitymetric_mean":
        sql = """ UPDATE osdbfire
                    SET firessp1262030metric_mean = %s
                    WHERE key = %s"""
    elif field == "firessp1262040fireProbabilitymetric_mean":
        sql = """ UPDATE osdbfire
                    SET firessp1262040metric_mean = %s
                    WHERE key = %s"""
    elif field == "firessp1262050fireProbabilitymetric_mean":
        sql = """ UPDATE osdbfire
                    SET firessp1262050metric_mean = %s
                    WHERE key = %s"""
    elif field == "firessp1262075fireProbabilitymetric_mean":
        sql = """ UPDATE osdbfire
                    SET firessp1262075metric_mean = %s
                    WHERE key = %s"""
                   
    elif field == "firessp1262100fireProbabilitymetric_mean":
        sql = """ UPDATE osdbfire
                    SET firessp1262100metric_mean = %s
                    WHERE key = %s"""
    elif field == "firessp5852020fireProbabilitymetric_mean":
        sql = """ UPDATE osdbfire
                    SET firessp5852020metric_mean = %s
                    WHERE key = %s"""
    elif field == "firessp5852030fireProbabilitymetric_mean":
        sql = """ UPDATE osdbfire
                    SET firessp5852030metric_mean = %s
                    WHERE key = %s"""
    elif field == "firessp5852040fireProbabilitymetric_mean":
        sql = """ UPDATE osdbfire
                    SET firessp5852040metric_mean = %s
                    WHERE key = %s"""
    elif field == "firessp5852050fireProbabilitymetric_mean":
        sql = """ UPDATE osdbfire
                    SET firessp5852050metric_mean = %s
                    WHERE key = %s"""
    elif field == "firessp5852075fireProbabilitymetric_mean":
        sql = """ UPDATE osdbfire
                    SET firessp5852075metric_mean = %s
                    WHERE key = %s"""
    elif field == "firessp5852100fireProbabilitymetric_mean":
        sql = """ UPDATE osdbfire
                    SET firessp5852100metric_mean = %s
                    WHERE key = %s"""
    else:
        print("Wrong Metric*:",key,field,metric)
        return 0

    updated_rows = 0
    try:
       
        cursor.execute(sql, (metric, key))
        # get the number of updated rows
        updated_rows = cursor.rowcount
        # Commit the changes to the database
        connection.commit()
        # Close communication with the PostgreSQL database
        #cur.close()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
#     finally:
#         if conn is not None:
#             conn.close()

    return updated_rows


def findFieldFire(peril,scenario,year,metric):
    #print(peril,scenario,year,metric)
    if (peril=="fire")and (scenario=="ssp126") and (year==2020) and (metric=="fireProbability"):
        return "firessp1262020fireProbabilitymetric_mean"
    elif (peril=="fire")and (scenario=="ssp126") and (year==2030) and (metric=="fireProbability"):
        return "firessp1262030fireProbabilitymetric_mean"
    elif (peril=="fire")and (scenario=="ssp126") and (year==2040) and (metric=="fireProbability"):
        return "firessp1262040fireProbabilitymetric_mean"
    elif (peril=="fire")and (scenario=="ssp126") and (year==2050) and (metric=="fireProbability"):
        return "firessp1262050fireProbabilitymetric_mean"
    elif (peril=="fire")and (scenario=="ssp126") and (year==2075) and (metric=="fireProbability"):
        return "firessp1262075fireProbabilitymetric_mean"
    elif (peril=="fire")and (scenario=="ssp126") and (year==2100) and (metric=="fireProbability"):
        return "firessp1262100fireProbabilitymetric_mean"
    elif (peril=="fire")and (scenario=="ssp585") and (year==2020) and (metric=="fireProbability"):
        return "firessp5852020fireProbabilitymetric_mean"
    elif (peril=="fire")and (scenario=="ssp585") and (year==2030) and (metric=="fireProbability"):
        return "firessp5852030fireProbabilitymetric_mean"
    elif (peril=="fire")and (scenario=="ssp585") and (year==2040) and (metric=="fireProbability"):
        return "firessp5852040fireProbabilitymetric_mean"
    elif (peril=="fire")and (scenario=="ssp585") and (year==2050) and (metric=="fireProbability"):
        return "firessp5852050fireProbabilitymetric_mean"
    elif (peril=="fire")and (scenario=="ssp585") and (year==2075) and (metric=="fireProbability"):
        return "firessp5852075fireProbabilitymetric_mean"
    elif (peril=="fire")and (scenario=="ssp585") and (year==2100) and (metric=="fireProbability"):
        return "firessp5852100fireProbabilitymetric_mean"
    else:
        return "unknown"
    
def createKey (latitude,longitude):
    
    key = "{:.2f}".format(latitude)+"{:.2f}".format(longitude)
    return key
    
# fire = gpd.read_file("n00e005.geojsons")

# for index,row in fire.iterrows():
#     #print(row)
#     key = createKey(row["latitude"],row["longitude"])
#     field = findFieldFire(row["peril"],row["scenario"],row["year"],row["metric"])
#     fireProbability = row["metric_mean"]
#     update_fire(key,field,fireProbability) 


# files = glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/fire/fit_v3/fireProbability/agg_v2/ssp126/remap_v1/2040/*.geojsons")
# files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/fire/fit_v3/fireProbability/agg_v2/ssp126/remap_v1/2050/*.geojsons"))
# files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/fire/fit_v3/fireProbability/agg_v2/ssp126/remap_v1/2075/*.geojsons"))
# files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/fire/fit_v3/fireProbability/agg_v2/ssp126/remap_v1/2100/*.geojsons"))
# files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/fire/fit_v3/fireProbability/agg_v2/ssp126/remap_v1/2020/*.geojsons"))
# files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/fire/fit_v3/fireProbability/agg_v2/ssp126/remap_v1/2030/*.geojsons"))
# files = glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/fire/fit_v3/fireProbability/agg_v2/ssp585/remap_v1/2020/*.geojsons")
# files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/fire/fit_v3/fireProbability/agg_v2/ssp585/remap_v1/2030/*.geojsons"))
# files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/fire/fit_v3/fireProbability/agg_v2/ssp585/remap_v1/2040/*.geojsons"))
# files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/fire/fit_v3/fireProbability/agg_v2/ssp585/remap_v1/2050/*.geojsons"))
# files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/fire/fit_v3/fireProbability/agg_v2/ssp585/remap_v1/2075/*.geojsons"))
files = glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/fire/fit_v3/fireProbability/agg_v2/ssp585/remap_v1/2100/*.geojsons")

for file in files:
    print(file)
    fire = gpd.read_file(file)
    #print(fire)
    for index,row in fire.iterrows():
        #print(row)
        key = createKey(row["latitude"],row["longitude"])
        field = findFieldFire(row["peril"],row["scenario"],row["year"],row["metric"])
        fireProbability = row["metric_mean"]
        update_fire(key,field,fireProbability) 
    


connection.close()

# %%
import glob
files = glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/fire/fit_v3/fireProbability/agg_v2/ssp585/remap_v1/2020/*.geojsons")
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/fire/fit_v3/fireProbability/agg_v2/ssp585/remap_v1/2030/*.geojsons"))
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/fire/fit_v3/fireProbability/agg_v2/ssp585/remap_v1/2040/*.geojsons"))
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/fire/fit_v3/fireProbability/agg_v2/ssp585/remap_v1/2050/*.geojsons"))
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/fire/fit_v3/fireProbability/agg_v2/ssp585/remap_v1/2075/*.geojsons"))
files.extend(glob.glob("/Users/luismanalac/desktop/OS-Climate/osc-geotiff/reports/osc/reports/fire/fit_v3/fireProbability/agg_v2/ssp585/remap_v1/2100/*.geojsons"))
for file in files:
    print(file)

# %%
# !pwd
